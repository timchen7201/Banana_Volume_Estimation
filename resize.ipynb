# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("images/original/image_03-07-2020_01-00-05_AM.jpg")

# %%
img1 = img[200:1000,400:1200]
plt.imshow(img1)

# %%
img.size
# Out:
# 0
